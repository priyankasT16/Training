# %%
import folium
import os
import pandas as pd

# %%
map = folium.Map(location=[38.58,-99.09],zoom_start=6,title="Stamen Terrain")
fg=folium.FeatureGroup(name='My map')


os.getcwd()
# Out:
# 'C:\\Users\\priyanka.thakare\\Desktop\\Jupyter\\code\\app2\\code'

# %%
html="""Volcano name:<br>
<a href="https://www.google.com/search?q=%%22%s%%22" target="_blank">%s</a><br>
Height : %s m
"""

# %%
def color_producer(elevation):
    if elevation<1000:
        return 'green'
    elif elevation <= 3000 and elevation >= 1000:
        return 'orange'
    else:
        return 'red'

# %%
data=pd.read_csv('C:/Users/priyanka.thakare/Desktop/Jupyter/code/app2/data/Volcanoes.txt')
lat=list(data['LAT'])
lon=list(data['LON'])
elv=list(data['ELEV'])
name=list(data['NAME'])
for i,j,k,nm in zip(lat,lon,elv,name):
    iframe=folium.IFrame(html=html % (nm,nm,k),width=200,height=100)
    fg.add_child(folium.CircleMarker(location=[i,j],popup=folium.Popup(iframe),radius=6,fill_color=color_producer(k),
                                     color='grey',fill_capacity=0.7))
map.add_child(fg)
map.save("Map1.html")

# %%
data
# Out:
#     VOLCANX020    NUMBER            NAME       LOCATION  \
# 0        509.0  1201-01=           Baker  US-Washington
# 1        511.0  1201-02-    Glacier Peak  US-Washington
# 2        513.0  1201-03-         Rainier  US-Washington
# 3        515.0  1201-05-      St. Helens  US-Washington
# 4        516.0  1201-04-           Adams  US-Washington
# ..         ...       ...             ...            ...
# 57       580.0  1210-03-  Valles Caldera  US-New Mexico
# 58       581.0  1209-02-   Sunset Crater     US-Arizona
# 59       584.0  1203-20-           Amboy  US-California
# 60       586.0  1210-02-    Zuni-Bandera  US-New Mexico
# 61       588.0  1210-01-       Carrizozo  US-New Mexico
#
#                    STATUS    ELEV             TYPE TIMEFRAME        LAT  \
# 0              Historical  3285.0  Stratovolcanoes        D3  48.776798
# 1        Tephrochronology  3213.0    Stratovolcano        D4  48.111801
# 2        Dendrochronology  4392.0    Stratovolcano        D3  46.869801
# ...
